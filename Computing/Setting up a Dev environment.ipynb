# %% [markdown]
# <h3>Contents</h3>
#
# <br>[<b>Installs</b>](#Installs)

# %% [markdown]
# <a id='Dual Booting'></a>
# <h3 style="background-color:#616161;color:white">Dual Booting</h3>
#
# I would prefer to use a Virtual Machine but from what I've read and experienced I don't think (?) Tensorflow with GPU support can be run in a Virtual Machine. So I've opted for dual booting -- which is a headache as it's not as easy to kill and re-create if you need to and there's ALWAYS issues with drivers I feel.
#
# This is a decent set of instructions for dual booting:
# https://help.ubuntu.com/community/WindowsDualBoot
#
# Except - you have to turn Secure Boot off in the bios (at least on Dell computers). I'll write more instructions for my Dell XPS tower once it arrived in a few weeks.

# %% [markdown]
# <a id='Installs'></a>
# <h3 style="background-color:#616161;color:white">Installs</h3>

# %% [markdown]
# This tutorial assumes you have just completed a fresh install of Ubuntu and nothing else. Although this guy has written a better tutorial:
# http://guanghan.info/blog/en/my-works/building-our-personal-deep-learning-rig-gtx-1080-ubuntu-16-04-cuda-8-0rc-cudnn-7-tensorflowmxnetcaffedarknet/
#
#
# 1. Install <b>JDK or JSE</b>
#
#     * Open source version: sudo apt-get install openjdk-8-jdk
#
#     * Official version: sudo apt-get install oracle-java8-installer
#
# 2. Install the Scala Build Tool: http://www.scala-sbt.org/download.html
#
# 3. Install <b>Anaconda</b>
# * https://www.continuum.io/downloads
#
# 4. Install Docker: https://store.docker.com/editions/community/docker-ce-server-ubuntu
#
# 5. Install the Hortonworks Sandbox: https://hortonworks.com/downloads/
# https://hortonworks.com/hadoop-tutorial/setting-spark-development-environment-scala/
#
# 5. Install <b>PyCharm:</b>
#     * https://www.jetbrains.com/pycharm/download/#section=linux
#
# 6. Install emacs
#
# 7. Install Sqlite Browser:
#     * sudo add-apt-repository -y ppa:linuxgndu/sqlitebrowser
#     * sudo apt-get update
#     * sudo apt-get install sqlitebrowser
#
# 8. Install Pendulum on Anaconda
#     * conda install -c conda-forge pendulum=1.2.4

# %% [markdown]
# <a id='Ubuntu on VirtualBox on Windows setup'></a>
# <h3 style="background-color:#616161;color:white">Ubuntu on VirtualBox on Windows setup</h3>
#
# To setup a Tensorflow environment on Conda:
# * Install Oracle VirtualBox: https://www.liberiangeek.net/2015/06/how-to-install-and-use-virtualbox-on-windows-to-create-ubuntu-guest-machine/
# * To set up a shared folder:
# * https://www.howtogeek.com/189974/how-to-share-your-computers-files-with-a-virtual-machine/
# * sudo usermod -G vboxsf -a username
# * reboot

# %% [markdown]
# <a id='EnvironmentSetup'></a>
# <h3 style="background-color:#616161;color:white">Environment Setup</h3>
#
# To setup a Tensorflow environment on Conda:
# * conda create --name tensorflow python=3.5
# * source activate tensorflow
# * conda install jupyter
# * conda install scipy
# * conda install tensorflow
#
# Note: python=3.5 only needs to be specified so long as TF does not support 3.6
# Here we will set up an environment to work in within Conda. Conda allows several ready-made environments (see url) but we will opt for Tensroflow.
#
# See here for other environments: https://docs.continuum.io/anaconda/pkg-docs

# %% [markdown]
# <a id='Spark'></a>
# <h3 style="background-color:#616161;color:white">Spark</h3>
#
# To install Spark:
# 1. sudo apt-get update
# 2. Install JDK: sudo apt-get install default-jdk
# 3. Install IntelliJ and enable Spark during the Install
# 4. Download Spark from the website (do not run Pip if you want to use Scala) and extract and store
# 5. Add the bin path to PATH by:
#     - gedit ~/.profile
#     - add    /home/YourUserName/Installs/Spark/bin     after Path:
#     - (Change Installs/Spark to wherever you put it in your main directory)
#     - Type $PATH to view the paths from the terminal
#     - Test by typing spark-shell in the terminal window
#
#
# To run the python spark shell
# * Go to the main folder
# * Run ./bin/pyspark

# %% [markdown]
# <a id='Gensim'></a>
# <h3 style="background-color:#616161;color:white">Gensim</h3>
#
# * sudo apt-get install python3-dev build-essential
#
# then:
# * sudo pip3 install --upgrade gensim

# %% [markdown]
# <a id='DatabaseInstall'></a>
# <h3 style="background-color:#616161;color:white">Database Install</h3>
#
# Rather than going with the coventional choice of MySQL or HeidiSQL here (my preferred up till now) I've decided to give SQL Server 2017 a spin, primarily due to the investment Microsoft are making to integrate it with analytic tools like R and Python. For now it's in preview mode.
# https://docs.microsoft.com/en-us/sql/linux/sql-server-linux-setup-ubuntu

# %% [markdown]
# <a id='Misc'></a>
# <h3 style="background-color:#616161;color:white">Misc. Linux commands</h3>

# %% [raw]
# ######################################################
# ###   Compendium of Useful Command Line Commands   ###
# ######################################################
#
# 1. Ubuntu Install
#
# Update the software repository:         sudo apt-get update
#
# Install using apt-get:                  sudo apt-get install python-skimage
#
# Install Python package:                 sudo pip3 install <package name>
# or install list of packages:            sudo pip3 install -r requirements.txt
#
# -----------------------------------------------------------------------------
#
# 2. General commands
#
# Clear the screen:                       clear
#
# List files in vertical format:          ls -w 1
# To rename a file in file manager:       Select file and press F2
# To view the $PATH setting:              sed 's/:/\n/g' <<< "$PATH"
#
# -----------------------------------------------------------------------------
# 3. gksudo
# gksudo should be used if you need to run any GUI apps in admin mode. It sets the rigt user permissions for any files you create using the GUI.
#
# Opening file manager in admin mode:     gksudo nautilus
#
# Opening pycharm in admin mode:          gksudo pycharm
#
#
# -----------------------------------------------------------------------------
#
# 4. Virtual Servers
#
# Create a virtual server:                virtualenv -p /usr/bin/python3.6 virtualservername
#
# Create a VS for a previous version of Tensorflow:       virtualenv --system-site-packages -p /usr/bin/python3.6 tf0_12
#
# To activate a virtual server:           source bin/activate
#
#
# 5. GIT
# -----------------------------------------------------------------------------
#
# Clone from github to local dir:         git clone https://github.com/alrojo/tensorflow-tutorial.git
#
#
# Check git status:                       git status
# or:                                     git status --short
#
# Commit all changes & Upload to server:
# git add <file you want to add>
# git commit -m "Update"
# git push
#
# Add everything (inc. sub folders) to staging area & then commit (best not to use this): git add -A
#
#
# Get any updates from Github server: git fetch origin
#
#
# 6. Jupyter
# -------
# Convert to markdown:
# ipython nbconvert jekyll_test.ipynb --to markdown
#
#
#
# 7. AWS
# ----------------------------------------------------------------------------
#
# Testing locally using Mrjob:
# python myjob.py Test.txt
#
# Coursework specific:
# -----------------------
# python myjob_pagerank.py -r emr s3://mrjobinput260581/epinions.gz --output-dir=s3://mrjoboutput260581/output3 --no-output --disable-emr-debugging
# python myjob_pairs.py ./data/pg105.txt ./data/pg121.txt ./data/pg141.txt ./data/pg158.txt ./data/pg161.txt ./data/pg946.txt ./data/pg1212.txt ./data/pg1342.txt
#
#
# cat ./Test.txt | ./mymap.py | ./myreduce.py
#
#
#
# Directories:
# ------------
# cd /home/UserName/Documents/github/badrulalom.github.io
#
# Git commanads:
#
#
#
# Running the Jekyll server:
# --------------------------
# cd /home/UserName/Documents/github/badrulalom.github.io
# bundle exec jekyll serve
#
#
#
# ----------------------
# MariaDB
# Start: mysql -h localhost -u root -p
# Create database: Create database: create database masterDB
#
# Create User:
# CREATE USER 'UserName'@'localhost' IDENTIFIED BY 'Bq34xx11';
#
#
# Grant permission:
# GRANT ALL PRIVILEGES ON masterDB.* TO 'badrul'@'localhost';
# FLUSH PRIVILEGES;
#
# Delete a user: drop user 'UserName'@localhost;
#
#
# Django
# ----------
# https://docs.djangoproject.com/en/1.10/intro/tutorial01/
#
# Create app: python manage.py startapp mainsite
#
# Dell Setup:
# badrul@Badrul-UBUNTU:~/Documents/Online/Data-Science-Notes$ xinput set-prop "DLL06E4:01 06CB:7A13 Touchpad" "Synaptics Noise Cancellation" 20 20
# username@UserName-UBUNTU:~/Documents/Online/Data-Science-Notes$ xinput set-prop "DLL06E4:01 06CB:7A13 Touchpad" "Synaptics Finger" 50 90 255
#
#
# Combining PDFs
# sudo apt-get install poppler-utils
# pdfunite file1.pdf file2.pdf file3.pdf outputfile.pdf
#
#
# Installing third party apps
# ---------------------------
# cd /Downloads
#
# sudo dpkg -i awesome_new_app.deb
#
# sudo apt-get -f install
#
# To get headphones to work:
# alsamixer
# Change MM and Master, keep Speakers down
#
# Check what images you have installed
# docker images
#
# Clean up unused containers:
# docker rm -v $(docker ps -a -q -f status=exited)
#
# List docker-machines
# docker-machine ls
#
# # Start
# docker-machine start docker2
# eval $(docker-machine env docker2)
#
# To update docker:
# sudo apt-get update
# sudo apt-get upgrade docker-engine
