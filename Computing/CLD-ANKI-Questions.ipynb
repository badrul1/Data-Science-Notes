# %% [markdown]
# $\newcommand{\m}[1]{\mathbf{#1}}$
# $\newcommand{\x}[1]{\textrm{#1}}$
#
# $\newcommand{\E}{\mathrm{E}}$
# $\newcommand{\var}{\mathrm{Var}}$
# $\newcommand{\cov}{\mathrm{Cov}}$

# %% [markdown]
# ## Questions
#
# ### Chapter 1 - Introduction to Cloud Computing & Cloud Computing Technologies and Types
#
#
#
# **Q) What is meant by Cloud Computing and utility?**
#
# Answer:
#
# - Cloud Computing = Big data processing, Utility Computing, Everything as a Service
# - Utility = Metered -> Pay as you go, on demand, uniform and available.
#
# ___
#
# **Q) What are the benefits of utility computing?**
#
# Answer:
#
# - Cost -> Capital vs operating (lower barrier to entry for big data)
# - Scalability -> "infinite" capacity
# - Elasticity -> Scale up and down
#
# ___
#
#
# **Q) What are the 5 priciples of cloud computing?**
#
# Answer:
# 1. Pooled Resources - Available to any subscribing users, infrastructure as code
# 2. Virtualization - Higher % of hardware utilisation
# 3. Elasticity - Dynamic scale without CAPEX (can use load balancers)
# 4. Automation - Building, deploying, configuring, provisioning, and moving, all without manual intervention
# 5. Metered Billing - pay for what you use
#
# ___
#
#
# **Q) The 4 benefits of Cloud Computing**
#
# Answer:
# 1. Economic benefits of the change from capital expenses (CAPEX) to operational expenses (OPEX)
# 2. Agility benefits from not having to procure and provision servers
# 3. Efficiency benefits that may lead to competitive advantages
# 4. Security stronger and better in the cloud
#
# ___
#
#
# **Q) What 3 types of scenario does Cloud Computing make sense?**
#
# Answer:
# 1. Limited lifetime requirement or short-term need - e.g. short term projects, POC's
# 2. Scale variability or volatility - e.g. Viral websites that have large fluctuations
# 3. Nonstrategic applications or low organizational value - e.g. Dev wiki
#
# ___
#
#
# **Q) Give a usage graph where Cloud makes sense?**
#
# Answer:
#
# ![cloud](img/cap.png)
#
# ___
#
#
# **Q) Where Does the Cloud Not Make Sense?**
#
# Answer:
#
# 1. Legacy systems – e.g. old software that requires specific hardware
# 2. Applications involving real-time or mission critical scenarios – e.g. certain databases or broadcasting devices that are time critical.
# 3. Applications dealing with confidential data - e.g. Home Office
#
# ___
#
# **Q) What does IaaS, Paas and SaaS stand for? Give examples of each**
#
# Answer:
# - IaaS = Infrastructure as a Service e.g. EC2
# - PaaS = Platform as a Service e.g. Heroku or Google Apps Engine
# - SaaS = Software as a Service e.g. gmail
#
# ___
#
# **Q) What are the 4 main cloud types?**
#
# Answer:
# - Public Cloud - The cloud made available to the general public by a service provider, either free or offered on a pay-per-use model.
# - Private Cloud - The cloud operated solely for a single organization and not shared with others.
# - Community Cloud - The cloud shared between several organizations from a specific community with common concerns.
# - Hybrid Cloud - A composition of two or more different types of clouds.
#
# ___
#
#
# **Q) Is AWS IaaS, PaaS or SaaS?**
#
# Answer:
# - AWS is IaaS (EC2) and PaaS (Elastic bean stalk)
#
# ___
#
# **Q) What does S3 stand for?**
#
# Answer:
# - Simple Storage Service
# ___
#
# **Q) What does EC2 stand for?**
#
# Answer:
# - Elastic Compute Cloud
#
# ___
#
#
# **Q) What is Route 53?**
#
# Answer:
# - It's highly available and scalable cloud Domain Name System (DNS) web service.
#
# ___
#
# **Q) What is EBS ?**
#
# Answer:
# - Elastic bean stalk - Allows 1 click deployment to AWS from Eclipse/Visual Studio.
#
# ___
#
# **Q) What is IAM?**
#
# Answer:
# - Identity and Access Management
#
# ___
#
#
# **Q) What does EC2 stand for?**
#
# Answer:
# - Simple Storage Service
#
# ___
#
# **Q) What is GAE and when would you use it?**
#
# Answer:
# - Google Apps Engine - use instead of AWS if you need to be quick to market and have no code already.
#
# ___
#
# **Q) What is Azure and when would you use it?**
#
# Answer:
# - Microsoft's cloud offering - You might use if you already use the .NET and SQL Server portions of the Microsoft stack
# - Or have existing code developed to those Microsoft APIs
#
# ___
#
#
# **Q) QUESTION ?**
#
# Answer:
# -

# %% [markdown]
# ### Chapter 2 - Parallel Computing and Distributed Systems
#
#
# **Q) What paradigm is the Cloud solution based on?**
#
# Answer:
# - Parallel & Distributed
# - Cloud applications are based on the client-server paradigm with a relatively simple software, a thinclient, running on the user's machine, while the computations are carried out on the cloud.
#
# ___
#
#
# **Q) What does Parallel Computing allow?**
#
# Answer:
# - solve problems demanding resources not available on a single system
# - reduce the time required to obtain a solution
# ___
#
# **Q) What is the formula for parallel computing speedup?**
#
# Answer:
# - The speed-up S measures the effectiveness of parallelization: S(N) = T(1) / T(N)
# - T(1): the execution time of the sequential computation
# - T(N): the execution time when N parallel computations are carried out
# ___
#
#
# **Q) What are the two laws affecting parallelism speedup? When do you use each?**
#
# Answer:
# - Amdahl’s law - problem/dataset size is fixed
# - Gustafson’s law - when computing time is fixed
#
# ___
#
#
# **Q) What is Amdahl's law?**
#
# Answer:
# - When the problem/dataset size is fixed, Amdahl’s Law: If α is the fraction of running time a sequential program spends on non-parallelizable segments of the computation then: S(N) = 1 / [α + (1-α)/N] < 1 / α
# - The speedup of a program using multiple processors in parallel computing is limited by the sequential fraction of the program.
#
# ![amdahl](img/amdahl.png)
# ![amdahl2](img/amdahl2.png)
#
# ___
#
#
# **Q) What is a Embarrassingly Parallel Problem?**
#
# Answer:
# - Little or no effort is required to separate the problem into a number of parallel tasks, i.e., α ≈ 0 – Often the case where there exists no dependency (or communication) between those parallel tasks
#
# ___
#
#
# **Q) What is Gustafson’s Law ?**
#
# Answer:
# - When the computing time available is fixed, the problem/dataset size is allowed to change, i.e., can be arbitrarily large.
# - Gustafson’s Law - The amount of work assigned to each process keeps the same
# - The scaled speed-up with N parallel processes: S(N) = α + N (1- α) = N - α (N-1) The limitations of the sequential part of a code can be balanced by increasing the problem size.
#
# ![gustafson](img/gustafson.png)
# ![gustafson2](img/gustafson2.png)
#
# ___
#
#
# **Q) What is Data Parallelism vs Task Parallelism?**
#
# Answer:
# - Data parallelism: the data is partitioned into several blocks and the blocks are processed in parallel
# - e.g. Single Program Multiple Data (SPMD): multiple copies of the same program run concurrently, each one on a different data block
#
# - Task parallelism: the problem is decomposed into tasks that can be carried out concurrently
# ___
#
#
#
#
# **Q) What is SPMD?**
#
# Answer:
# - Single Program Multiple Data (SPMD): multiple copies of the same program run concurrently, each one on a different data block is a form of data parallelism.
#
# ___
#
# **Q) What is a deadlock ?**
#
# Answer:
# - A deadlock is a situation in which two or more competing actions are each waiting for the other to finish, and thus neither ever does AKA. “Catch-22”
#
# ___
#
#
# **Q) What are the Coffman conditions? How many of them are there and what are they?**
#
# Answer:
# - Necessary and Sufficient Deadlock Conditions. Coffman (1971) identified four (4) conditions that must hold simultaneously for there to be a deadlock.
#
# 1. Mutual exclusion – At least one resource must be non-sharable, only one process/thread may use the resource at any given time.
# 2. Hold and wait – At least one processes/thread must hold one or more resources and wait for others.
# 3. No preemption – The scheduler or monitor should not be able to force a process/thread holding a resource to relinquish it.
# 4) Circular wait – Given the set of n processes/threads {P1, P2 , P3 , …,Pn }. P1 waits for a resource held by P2, P2 waits for a resource held by P3, and so on, Pn waits for a resource held by P1.
#
#
# ___
#
#
# **Q) What is a live lock?**
#
# Answer:
# - A livelock is similar to a deadlock, except that the states of the processes involved constantly change with regard to one another, none progressing.
# ___
#
#
# **Q) What is concurrency and why is it challenging?**
#
# Answer:
# - Concurrency is important Many cloud applications are data-intensive and use a number of instances which run concurrently
# - Concurrency is challenging- It could lead to race conditions, an undesirable effect when the results of concurrent execution depend on the sequence or timing of events - Shared resources must be protected by locks / semaphores / monitors to ensure serial access. These are usually complicated and can sometimes go wrong.
#
# ___
#
#
# **Q) What are race conditions?**
#
# Answer:
# - A race condition is an undesirable situation that occurs when a device or system attempts to perform two or more operations at the same time, but because of the nature of the device or system, the operations must be done in the proper sequence to be done correctly.
#
# ![race](img/race.png)
#
# ___
#
#
# **Q) What is a Distributed System?**
#
# Answer:
# - A distributed system is an application that coordinates the actions of several computers to achieve a specific task: 1. By exchanging messages which are pieces of data that convey some information - “shared-nothing” architecture: no shared memory/disk
# 2. Client (nodes) and Server (nodes) are communicating software components we assimilate them with the machines they run on.
# This relies on a network connected via LAN (possibly in racks or groups of clusters) or P2P
#
# ![dist](img/dist.png)
# ___
#
#
# **Q) What is the data-centric approach for a Distributed Systems?**
#
# Answer:
# - disk transfer rate is a bottleneck for large scale data management: parallelization and distribution of the data on many machines is a means to eliminate this bottleneck
# - write once, read many: distributed storage is appropriate for large files that are written once and then repeatedly scanned
# - data locality: bandwidth is a scarce resource, so program should be “pushed” near the data they must access to
#
# ___
#
#
# **Q) With regards to a distributed system, what is replication and consistency?**
#
# Answer:
# - Distribution also gives an opportunity to reinforce the security of data with replication
#  - Replication: a mechanism that copies data item located on a machine A to a remote machine B
#  - Consistency: ability of a system to behave as if the transaction of each user always run in isolation from other transactions, and never fails
#   - Difficult in centralized systems because of multi-users and concurrence. Even more difficult in distributed systems because of replicas
#
#
# ___
#
#
# **Q) Draw out diagram of a) Eager replication with primary copy, b) Lazy replication with primary copy(master slave), c) eager replication (distributed), d) Lazy replication distributed (Master-Master)**
#
# Answer:
# ![replication](img/replication.png)
#
#
# ___
#
#
# **Q) Does strong consistency require a slow syncronous connection or a fast light one? Give an example of something that may require strong consistency**
#
# Answer:
# - Strong consistency: requires a (slow) synchronous replication.
#
# SQL databases favour consistency over availability- The two phase commit (2PC) protocol is the algorithm of choice to ensure strong consistency (ACID properties) in a distributed setting. One of the reasons of the ’NoSQL’ trend
#
# ___
#
#
# **Q) What is weak consistency? Give an example of when this might be acceptable, Can you think of when this might cause problems?**
#
# Answer:
# - Weak Consistency- accepts to serve some requests with outdated data. Maintains **eventual consistency**, some file systems or metrics may not need to report the most up to date and current metrics. Data reconciliation: in a system that is not eventually consistent, conflicts occur and the application must determine the new current one given the two conflicting copies.
#
#
# ___
#
#
# **Q) What are the 4 properties of a distributed system?**
#
# Answer: 4 Properties of a Distributed System
# 1. Reliability -  ability of a distributed system to deliver its services even when one or several of its software/hardware components fail. Assumption that a participating machine affected by a failure can always be replaced by another one, and not prevent the completion of a requested task – Needs redundancy of both software and data.
# 2. Scalability -  ability of a distributed system to continuously evolve in order to support an ever-growing amount of tasks.
# 3. Availability - failure detection via heartbeats and quick restart protocols. Replication on several nodes
# 4. Efficiency - Can be measured in 2 ways: 1. The response time (or latency) which denotes the delay to obtain the first item, 2. The throughput (or bandwidth) which denotes the number of items delivered in a given period unit (e.g., a second)
#
#
# ___
#
#
# **Q) What is the CAP theorm? Draw a diagram supporting this**
#
# Answer: No distributed system can simultaneously provide all three of the following properties:
# - Consistency : all nodes see the same data at the same time
# - Availability: node failures do not prevent survivors from continuing to operate
# - Partition tolerance: the system continues to operate despite arbitrary message loss
#
# ![captheorm](img/capt.png)
#
# ___
#
#
# **Q) How is failure handled in centralised systems? Give an example of this**
#
# Answer:
# - The state of a (data) system is the set of item committed by the application.
# - Updating “in place” is considered as inefficient because of disk seeks. Instead, updates are written in main memory and in a sequential log file.
# - Failure? The main memory is lost, but all the committed transactions are in the log: a REDO operations is carried out when the system restarts
# ___
#
# **Q) How is failure handled in distributed systems?**
#
# Answer:
# - When do we know that a component is in failed state? Periodically send message to each participant.
# - Does the centralized recovery still hold? Yes, providing the log file is accessible
# ___
#
#
# **Q) What is a space time diagram? What do black circles represent? What do different lines represent?**
#
# Answer:
# - A space-time diagram displays local and communication events during a process lifetime.
# - Black circles = local events
# - Different lines = process lines with connecting ones being communication events
#
# ___
#
# **Q) What is a Lamport Timestamp?**
#
# Answer:
# - The algorithm of Lamport timestamps is a simple algorithm used to determine the order of events in a distributed computer system. As different nodes or processes will typically not be perfectly synchronized, this algorithm is used to provide a partial ordering of events with minimal overhead, and conceptually provide a starting point for the more advanced vector clock method. They are named after their creator, Leslie Lamport.
#
# From His notes:
# - A process maps events to positive integers - lines of communication carry over the integer from other process lines. It ensures a global timestamp when processing communicate.
# - Creates a partial causal ordering of events between processes.
#
# ![lamport](img/lamport.png)
#
# ___
#
#
# **Q) What is a disadvantage of Lamport Timestamps? What technique would fix this?**
#
# Answer:
# - A Lamport clock does not allow a global ordering of all events. It lacks an important property, gap detection. Given two events e and e' and their logical clock values, LC(e) and LC(e'), it is impossible to establish if an event e" exists such that LC(e) < LC(e") < LC(e'). Vector clocks which contain info on all process states would fix this.
#
#
# ___
#
# **Q) What is a strong clock consistency condition?**
#
# Answer:
# -  Is two way, i.e., if a -> b then LC(a) < LC(b) and can be achieved with vector clocks.
# ___
#
#
# **Q) What is a Checkpoint-Restart Procedure?**
#
# Answer:
# - As many computations run for extended periods of time, restarting from a checkpoint rather than the beginning is prefered.
# ___
#
# **Q) What is the global snapshot algorithm, under what condition is this possible?**
#
# Answer:
# - You can construct the global snapshot view by combining all the indiviudal components, this is only possible when there is a global clock and all are taken at the same time.
#
# ___
#
# **Q) What does the Chandy-Lamport Algorithm do and what are the steps?**
#
# Answer:
# - Constructs a consistent global state via snapshots.
#
# 1. Process p0 sends to itself a “take snapshot” message.
# 2. Let pf be the process from which pi receives the take snapshot message for the first time. Upon receiving the message, the process pi records its local state σi and relays the message “take snapshot” along all its outgoing channels without executing any events on behalf of its underlying computation; channel state ξf,i is set to empty and process pi starts recording messages received over each of its incoming channels.
# 3. Let ps be the process from which pi receives the “take snapshot” message after the first time. Process pi stops recording messages along the incoming channel from ps and declares channel state ξs,i between processes ps and pi as those messages that have been recorded.
#
# ![chandy-lamport](img/chandy-lamport.png)
#
# ___
#
#
# **Q) What is a Paxos? What are the 2 phases?**
#
# Answer:
# - A family of protocols to reach consensus based on a finite state machine approach. Paxos protocol has two phases
# - Phase I
#  - Proposal preparation
#  - Proposal promise
# - Phase II
#  - Accept request
#  - Accepted
#
# - Processes run on processors and communicate through a network; processors and network may experience failures, but not Byzantine failures.
#
# - The Processors
#   - (i) operate at arbitrary speeds;
#   - (ii) have stable storage and may rejoin the protocol after a failure;
#   - (iii) send messages to one another.
# - The network:
#   - (i) may lose, reorder, or duplicate messages;
#   - (ii) messages are sent asynchronously; it may take arbitrary long time to reach the destination.
#
# ___
#
# **Q) What does paxos guarantee ?**
#
# Answer: 3 safety properties
# 1. Non-triviality: Only proposed values can be learned
# 2. Consistency: at most one value can be learned.
# 3. Liveness: if a value v has been proposed, eventually every learner will learn some value, provided that sufficient processors remain nonfaulty.
#
# ___
#
# **Q) What are 2 example Paxos applications?**
#
# Answer:
# - Apache Zookepper
# - Google Chubby
#
# ___
#
#
# **Q) What are consensus protocols?**
#
# Answer:
# - All the processes in a distributed system must agree on a data value, e.g. whether to commit a value to a DB.
# ___
#
# **Q) What is a Crash Failure and what is a Byzantine failure?**
#
# Answer:
# - Crash failure: the process abruptly stops and does not resume.
# - Byzantine failure: the process fail in arbitrary ways (due to malfunctioning hardware, buggy software, malicious)
#  - Omission failures, e.g., failing to receive a request or send a response attacks
#  - Commission failures, e.g., corrupting the local state, sending an incorrect/inconsistent response to the request.
# ___
#
#
# **Q) What is REST?**
#
# Answer:
# - “REpresentational State Transfer” - not a standard but does perscribe the use of standards. e.g. http, uri
# - “Representation State Transfer is intended to evoke an image of how a well-designed Web application behaves: a network of web pages (a virtual state-machine), where the user progresses through an application by selecting links (state transitions), resulting in the next page (representing the next state of the application) being transferred to the user and rendered for their use.” --- Roy Fielding
#
# ___
#
#
# **Q) What is a Resource?**
#
# Answer:
# - Things vs Actions (Nouns vs Verbs) In contrast to SOAP. A resource can be essentially any coherent & meaningful concept that may be addressed
# - Identified by URIs - Multiple URIs may refer to the same resource
#
# ___
#
#
# **Q) What is a Representation?**
#
# Answer:
# - A document that captures the current or intended state of a resource
# - Example
#  - Resource: person (Dr Zhang)
#  - Service: contact information (GET)
#  - Representation: name, address, phone-number, etc.
# - Typically in JSON or XML format
# ___
#
#
# **Q) What are the 4 HTTP methods and how are they different for resource collection and element?**
#
# Answer: Resource Collection e.g. example.com/resource/
# 1. GET: List the URIs and perhaps other details of the collection's members
# 2. PUT: Replace the entire collection with another collection
# 3. POST: Create a new entry in the collection. The new entry's URI is assigned automatically and is usually returned by the operation
# 4. DELETE: Delete the entire collection
#
# Element e.g. example.com/resource/item12 :
# 1. GET: Retrieve a representation of the addressed member of the collection, expressed in an appropriate Internet media type
# 2. PUT: Replace the addressed member of the collection, or if it doesn't exist, create it
# 3. POST: Not generally used. Treat the addressed member as a collection in its own right and create a new entry in it.
# 4. DELETE: Delete the addressed member of the collection.
#
# ___
#
#
# **Q) What does nullipotent and idempotent mean? What HTTP methods belong to which?**
#
# Answer:
# - GET = nullipotent which means every time it's called it has no effect on the resource.
# - GET, PUT and DELETE = idempotent meaning multiple identical requests should have the same effect as a single request
# ___
#
#
# **Q) What HTTP methods would you use for a) retriving a list of books b) placing orders?**
#
# Answer:
# a. List all books - GET
# b. Place orders - POST
# ___
#
#
# **Q) What are the HTTP status codes?**
#
# Answer:
# - 200: OK
# - 201: Created
# - 400: Bad Request
# - 401: Unauthorized
# - 404: Not Found
# - 405: Method Not Allowed
# - 409: Conflict
# - 500: Internal Server Error
# ___
#
#
# **Q) What is ACID?**
#
# Answer:
# - Atomicity
# - Consistency
# - Isolation
# - Durability and is used for Databases transactions.
#
# ___
#
#
# **Q) What are the 6 'being RESTFul' Architectureal constraints?**
#
# Answer:
# 1. Client-Server - Assume a distributed architecture that consists of clients and servers. Clients initiate requests to servers. Separation of concerns
# 2. Uniform Interface - All resources are accessed with a generic interface between client and server. This It simplifies and decouples the architecture, which enables each part to evolve independently which is Fundamental to RESTful design:
#  - URIs (resource names)
#  - HTTP verbs (GET, PUT, POST, DELETE)
#  - HTTP response (status, body)
# 3. Stateless - Server contains no client state. Each request from any client to server must contain enough context (i.e., all the information necessary) to process it. All messages are self-descriptive-  Any session state is held on the client.
# 4. Cacheable - To improve network efficiency, clients should be able to cache responses (representations). Therefore responses must label themselves as cacheable, or not, to prevent clients reusing stale or inappropriate data.
# 5. Layered System - A client cannot ordinarily tell whether it is connected directly to the end server, or to an intermediary along the way proxies, gateways, and firewalls etc. Intermediary servers may improve system scalability (e.g., by enabling load-balancing and providing shared caches) and they may also enforce security policies
# 6) Code on Demand - Servers are able to temporarily extend or customize the functionality of a client by the transfer of executable code:
#  - compiled components, e.g., Java applets
#  - client-side scripts, e.g., JavaScript. This is the only optional constraint
#
# ___
#
# **Q) What 6 features does being  RESTful promote?**
#
# Answer:
# - Enables scalability, simplicity, modifiability, visibility, portability, and reliability
#
# ___
#
# **Q) What is REST vs SOAP?**
#
# Answer:
# - REST reuses the vocabulary of the well-known, well-defined HTTP protocol
# - SOAP encourages each application designer to define new, application specific methods that supplant HTTP methods
#  - It disregards many of HTTP's existing capabilities (such as authentication, caching, and content-type negotiation)
#  - It can work equally well over raw TCP, named pipes, message queues, etc.

# %% [markdown]
# ### Chapter 3 - Big Data
#
# ___
#
# **Q) What are the 3 V's of big data?**
#
# Answer:
# - Big Volume
# - Big Velocity
# - Big Variety
#
# ___
#
# **Q) What is OLAP?**
#
# Answer:
# - OLAP is an acronym for Online Analytical Processing.
# ___
#
# **Q) What is the law of large numbers?**
#
# Answer:
# - The Law of Large Numbers states that as you perform more experiments you get closer to the real value.
# ___
#
# **Q) What is the Rhine Paradox?**
#
# Answer:
# - Joseph Rhine was a parapsychologist in the 1950’s who hypothesized that some people had Extra Sensory Perception (ESP). He devised an experiment where subjects were asked to guess 10 hidden cards: red or blue. He discovered that almost 1 in 1000 had ESP: they were able to get all 10 right!
# - He told these people they had ESP and called them in for another test of the same type – Alas, he discovered that almost all of them had lost their ESP.
#
# - This is used to say that the bonferroni principle -> if you look hard enough for patterns in enough data you will find it.
#
#
# **Q) What is GFS?**
#
# Answer:
# - Google File System
# ___
#
# **Q) What is HDFS?**
#
# Answer:
# - Hadoop Distributed File System (HDFS) – a distributed file-system that stores data on commodity machines, providing very high aggregate bandwidth across the cluster
#
#
# ___

# %% [markdown]
# ### Chapter 4 - MapReduce and Hadoop

# %% [markdown]
# ### Chapter 5&6 - Practical Lab Class & Reading Week

# %% [markdown]
# ### Chapter 7 - Developing MapReduce Programs

# %% [markdown]
# ### Chapter 8 - Link Analysis in the Cloud
#
#
# ___
#
# **Q) What is OLTP?**
#
# Answer:
# - Online Transaction Processing (OLTP)
#
# ___
#
# **Q) What is the difference between OLAP and OLTP?**
#
# Answer:
# -
#
# ___
#
#
# **Q)What is ETL? When is it used?**
#
# Answer:
# - Extract, transform and load
# - Extract records from OLTP database into OLAP
#
# ___

# %% [markdown]
# ### Chapter 9 - Data Management in the Cloud

# %% [markdown]
# ### Chapter 10 - Information Retrieval in the Cloud

# %% [markdown]
# ### Chapter 11 - Beyond MapReduce (NOT EXAMINABLE)

# %% [markdown]
# ### Chapter x - EXAM QUESTIONS
